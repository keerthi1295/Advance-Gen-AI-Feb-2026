# %% [markdown]
# 1. Difference between "Love" and "love" in NLP
# In NLP, "Love" and "love" are treated as different words because machines are case-sensitive. Without preprocessing, they are considered separate tokens, which increases vocabulary size unnecessarily. Lowercasing helps treat them as the same word.
#
# 2. What happens if stopwords are not removed?
# If stopwords are not removed, the dataset may contain too many common words like "is", "the", "and", which add noise and reduce model efficiency. This can also increase computation time and reduce accuracy.
#
# 3. Two scenarios where removing stopwords is harmful
#
# Sentiment analysis: Words like "not" are important (e.g., "not good" vs "good").
# Question answering/search: Words like "what", "how", "when" are meaningful and should not be removed.
#
# 4. Stemming vs Lemmatization
#
# Stemming: Cuts words to root form (e.g., "running" → "run") but may not be meaningful.
# Lemmatization: Converts words to proper base form using meaning (e.g., "better" → "good"). It is more accurate than stemming.

# %%
import re

def preprocess_text(text):
    """
    Advanced NLP preprocessing function

    Steps:
    - Lowercasing
    - Remove URLs & emails
    - Remove numbers
    - Handle repeated characters
    - Remove special characters & emojis
    - Remove extra spaces
    - Tokenization
    - Remove short tokens (≤2) except 'no', 'not'
    """

    # 1. Handle edge cases
    if not text or not isinstance(text, str):
        return [], ""

    # 2. Convert to lowercase
    text = text.lower()

    # 3. Remove URLs
    text = re.sub(r"http\S+|www\S+", "", text)

    # 4. Remove email-like patterns
    text = re.sub(r"\S+@\S+", "", text)

    # 5. Remove numbers
    text = re.sub(r"\d+", "", text)

    # 6. Handle repeated characters (soooo → so)
    text = re.sub(r'(.)\1{2,}', r'\1', text)

    # 7. Remove special characters (including emojis)
    text = re.sub(r"[^\w\s]", "", text)

    # 8. Remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    # 9. Tokenization
    tokens = text.split()

    # 10. Remove short tokens (≤2) except 'no', 'not'
    tokens = [word for word in tokens if len(word) > 2 or word in ['no', 'not']]

    # 11. Create cleaned sentence
    cleaned_sentence = " ".join(tokens)

    return tokens, cleaned_sentence

# %%
test_cases = [
    "I have 2 dogs",                      # numbers
    "This   is   good",                   # extra spaces
    "soooo goooood!!!",                  # repeated chars
    "WOW!!! This is GREAT!!!",           # lowercase
    "Visit http://example.com now",      # URL
    "Contact me at test@gmail.com",      # email
    "No I am not happy",                 # keep 'no', 'not'
    "OK hi go",                          # remove short words
]

for text in test_cases:
    tokens, cleaned = preprocess_text(text)
    print("Original:", text)
    print("Tokens:", tokens)
    print("Cleaned:", cleaned)
    print("-" * 40)
# Out:
# Original: I have 2 dogs
# Tokens: ['have', 'dogs']
# Cleaned: have dogs
# ----------------------------------------
# Original: This   is   good
# Tokens: ['this', 'good']
# Cleaned: this good
# ----------------------------------------
# Original: soooo goooood!!!
# Tokens: ['god']
# Cleaned: god
# ----------------------------------------
# Original: WOW!!! This is GREAT!!!
# Tokens: ['wow', 'this', 'great']
# Cleaned: wow this great
# ----------------------------------------
# Original: Visit http://example.com now
# Tokens: ['visit', 'now']
# Cleaned: visit now
# ----------------------------------------
# Original: Contact me at test@gmail.com
# Tokens: ['contact']
# Cleaned: contact
# ----------------------------------------
# Original: No I am not happy
# Tokens: ['no', 'not', 'happy']
# Cleaned: no not happy
# ----------------------------------------
# Original: OK hi go
# Tokens: []
# Cleaned:
# ----------------------------------------

# %%
sample_inputs = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]

# Run preprocessing and display results
for text in sample_inputs:
    tokens, cleaned = preprocess_text(text)

    print("Original Text   :", text)
    print("Cleaned Tokens  :", tokens)
    print("Cleaned Sentence:", cleaned)
    print("-" * 60)
# Out:
# Original Text   : Get 100% FREE access now!!!
# Cleaned Tokens  : ['get', 'free', 'access', 'now']
# Cleaned Sentence: get free access now
# ------------------------------------------------------------
# Original Text   : I absolutely looooved this product 😍😍
# Cleaned Tokens  : ['absolutely', 'loved', 'this', 'product']
# Cleaned Sentence: absolutely loved this product
# ------------------------------------------------------------
# Original Text   : Worst service ever... 0/10
# Cleaned Tokens  : ['worst', 'service', 'ever']
# Cleaned Sentence: worst service ever
# ------------------------------------------------------------
# Original Text   : Call me at 9876543210
# Cleaned Tokens  : ['call']
# Cleaned Sentence: call
# ------------------------------------------------------------
# Original Text   : This is THE best course!!!
# Cleaned Tokens  : ['this', 'the', 'best', 'course']
# Cleaned Sentence: this the best course
# ------------------------------------------------------------
# Original Text   : Visit https://openai.com now!
# Cleaned Tokens  : ['visit', 'now']
# Cleaned Sentence: visit now
# ------------------------------------------------------------
# Original Text   : Nooooo this is baaad!!!
# Cleaned Tokens  : ['no', 'this', 'bad']
# Cleaned Sentence: no this bad
# ------------------------------------------------------------
# Original Text   : OK OK OK I got it
# Cleaned Tokens  : ['got']
# Cleaned Sentence: got
# ------------------------------------------------------------
# Original Text   : Win $$$ now!!! Limited offer!!!
# Cleaned Tokens  : ['win', 'now', 'limited', 'offer']
# Cleaned Sentence: win now limited offer
# ------------------------------------------------------------
# Original Text   : I am not happy with this
# Cleaned Tokens  : ['not', 'happy', 'with', 'this']
# Cleaned Sentence: not happy with this
# ------------------------------------------------------------

# %%
import numpy as np

print("🔍 Token Analytics Results\n")

for i, text in enumerate(sample_inputs, 1):
    tokens, cleaned = preprocess_text(text)

    total_tokens = len(tokens)
    unique_tokens = len(set(tokens))
    avg_token_length = np.mean([len(t) for t in tokens]) if tokens else 0

    print(f"Sentence {i}")
    print(f"Original Text        : {text}")
    print(f"Tokens               : {tokens}")
    print(f"Total Tokens         : {total_tokens}")
    print(f"Unique Tokens        : {unique_tokens}")
    print(f"Average Token Length : {round(avg_token_length, 2)}")
    print("-" * 60)
# Out:
# 🔍 Token Analytics Results
#
# Sentence 1
# Original Text        : Get 100% FREE access now!!!
# Tokens               : ['get', 'free', 'access', 'now']
# Total Tokens         : 4
# Unique Tokens        : 4
# Average Token Length : 4.0
# ------------------------------------------------------------
# Sentence 2
# Original Text        : I absolutely looooved this product 😍😍
# Tokens               : ['absolutely', 'loved', 'this', 'product']
# Total Tokens         : 4
# Unique Tokens        : 4
# Average Token Length : 6.5
# ------------------------------------------------------------
# Sentence 3
# Original Text        : Worst service ever... 0/10
# Tokens               : ['worst', 'service', 'ever']
# Total Tokens         : 3
# Unique Tokens        : 3
# Average Token Length : 5.33
# ------------------------------------------------------------
# Sentence 4
# Original Text        : Call me at 9876543210
# Tokens               : ['call']
# Total Tokens         : 1
# Unique Tokens        : 1
# Average Token Length : 4.0
# ------------------------------------------------------------
# Sentence 5
# Original Text        : This is THE best course!!!
# Tokens               : ['this', 'the', 'best', 'course']
# Total Tokens         : 4
# Unique Tokens        : 4
# Average Token Length : 4.25
# ------------------------------------------------------------
# Sentence 6
# Original Text        : Visit https://openai.com now!
# Tokens               : ['visit', 'now']
# Total Tokens         : 2
# Unique Tokens        : 2
# Average Token Length : 4.0
# ------------------------------------------------------------
# Sentence 7
# Original Text        : Nooooo this is baaad!!!
# Tokens               : ['no', 'this', 'bad']
# Total Tokens         : 3
# Unique Tokens        : 3
# Average Token Length : 3.0
# ------------------------------------------------------------
# Sentence 8
# Original Text        : OK OK OK I got it
# Tokens               : ['got']
# Total Tokens         : 1
# Unique Tokens        : 1
# Average Token Length : 3.0
# ------------------------------------------------------------
# Sentence 9
# Original Text        : Win $$$ now!!! Limited offer!!!
# Tokens               : ['win', 'now', 'limited', 'offer']
# Total Tokens         : 4
# Unique Tokens        : 4
# Average Token Length : 4.5
# ------------------------------------------------------------
# Sentence 10
# Original Text        : I am not happy with this
# Tokens               : ['not', 'happy', 'with', 'this']
# Total Tokens         : 4
# Unique Tokens        : 4
# Average Token Length : 4.0
# ------------------------------------------------------------

# %%
from collections import Counter

# Step 1: Collect all tokens
all_tokens = []

for text in sample_inputs:
    tokens, _ = preprocess_text(text)
    all_tokens.extend(tokens)

# Step 2: Count frequencies
word_counts = Counter(all_tokens)

# Step 3: Top 10 most frequent words
print("🔝 Top 10 Most Frequent Words:\n")
for word, count in word_counts.most_common(10):
    print(f"{word} : {count}")

# Step 4: Top 5 least frequent words
print("\n🔻 Top 5 Least Frequent Words:\n")

# Sort ascending by frequency
least_common = sorted(word_counts.items(), key=lambda x: x[1])

for word, count in least_common[:5]:
    print(f"{word} : {count}")
# Out:
# 🔝 Top 10 Most Frequent Words:
#
# this : 4
# now : 3
# get : 1
# free : 1
# access : 1
# absolutely : 1
# loved : 1
# product : 1
# worst : 1
# service : 1
#
# 🔻 Top 5 Least Frequent Words:
#
# get : 1
# free : 1
# access : 1
# absolutely : 1
# loved : 1

# %%
def full_pipeline(text_list):
    """
    Full NLP preprocessing pipeline

    Input:
        text_list -> list of raw text sentences

    Output:
        Dictionary with:
        - all tokens combined
        - cleaned sentences
    """

    all_tokens = []
    clean_sentences = []

    for text in text_list:
        tokens, cleaned = preprocess_text(text)

        all_tokens.extend(tokens)
        clean_sentences.append(cleaned)

    return {
        "tokens": all_tokens,
        "clean_sentences": clean_sentences
    }


# Call the function OUTSIDE
output = full_pipeline(sample_inputs)

# Print results
print("All Tokens:\n", output["tokens"])
print("\nCleaned Sentences:\n", output["clean_sentences"])
# Out:
# All Tokens:
#  ['get', 'free', 'access', 'now', 'absolutely', 'loved', 'this', 'product', 'worst', 'service', 'ever', 'call', 'this', 'the', 'best', 'course', 'visit', 'now', 'no', 'this', 'bad', 'got', 'win', 'now', 'limited', 'offer', 'not', 'happy', 'with', 'this']
#
# Cleaned Sentences:
#  ['get free access now', 'absolutely loved this product', 'worst service ever', 'call', 'this the best course', 'visit now', 'no this bad', 'got', 'win now limited offer', 'not happy with this']

# %%
# Edge case inputs
edge_cases = [
    "",                # Empty string
    "😍🔥😂",          # Only emojis
    "1234567890"       # Only numbers
]

for text in edge_cases:
    tokens, cleaned = preprocess_text(text)

    print("Input            :", text)
    print("Tokens           :", tokens)
    print("Cleaned Sentence :", cleaned)
    print("-" * 50)
# Out:
# Input            :
# Tokens           : []
# Cleaned Sentence :
# --------------------------------------------------
# Input            : 😍🔥😂
# Tokens           : []
# Cleaned Sentence :
# --------------------------------------------------
# Input            : 1234567890
# Tokens           : []
# Cleaned Sentence :
# --------------------------------------------------
